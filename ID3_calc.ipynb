# %% [markdown]
# ##The ID3 algorithm that binarizes outcomes, the logic behind  decision trees.

# %%
import numpy as np
from math import log2

#medium calc
6/8 * log2(8/6) + 2/8 * log2(8/2)
# Out:
# 0.8112781244591327

# %%
#not medium calc
6/12 * log2(12/6) + 6/12 * log2(12/6)
#Useless?^
# Out:
# 1.0

# %%
#weighted average
8/20 * .811 + 12/20 * 1
# Out:
# 0.9244

# %%
#tall calc
4/5*log2(5/4) + 1/5 * log2(5)
# Out:
# 0.7219280948873623

# %%
#not tall calc
8/15 * log2(15/8) + 7/15 * log2(15/7)
# Out:
# 0.9967916319816366

# %%
#tall:not tall weighted average
5/20*.722 + 15/20*.997
# Out:
# 0.92825
